# %%
qus- 1  .  In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.


*
'hello'
-87.8
-
/
+
6


Answer:-
    
*            --> This is expression and airthmetic operator.
'hello'      --> This is string value .
-87.8        --> This is floating type value.
-            --> This is expression and airthmetic operator.
/            --> This is expression and airthmetic operator.
+             --> This is expression and airthmetic operator.
6             --> This is integer  type value.
-----------------------------------------------------------------------------------

ques.2.  What is the difference between string and variable?

Answer:- 
    
String : --> string is collection of character or value. It is close inside single or double quotes.
              example: 'ineuron',"ineuron"
variable: --> variable is  a container or box where we store our value inside memory by variable.it is called variable.
    example: a= 5 , here a is a variable.
 ----------------------------------------------------------------------------------------------------------------------


ques.3.  Describe three different data types.

Answer: -
    
integer: --> we can store only number value without decimals  like as 636,- 77.
boolean: --> we can  store  values only with two states: true or false
string : --> we can store value in only character with single or double quotes like as 'ineuron', "ineuron" 
--------------------------------------------------------------------------------------------------------------------------

ques.4.  What is an expression made up of? What do all expressions do?

Answer: -
    
An expression is a combination of operators and operands that is interpreted to produce some other value.There are three kinds of expressions: An arithmetic expression evaluates to a single arithmetic value.
A character expression evaluates to a single value of type character. A logical or relational expression evaluates to a single logical value. All expressions evaluate (that is, reduce) to a single value.
------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------    
 
ques.5.This assignment statements, like spam = 10. What is the difference between an
expression and a statement?

Answer: -

An expression is a combination of operators and operands that is interpreted to produce some other value.An expression evaluates to a single value. A statement does not.
----------------------------------------------------------------------------------------------------------------------------------------------------------------
ques.6. After running the following code, what does the variable bacon contain?
        bacon = 22
        bacon + 1
Answer: - After running the code bacon would contain 22 because bacon + 1 expression does not reassign the value in bacon  (we need an assignment statement: bacon = bacon + 1) .
    
         bacon = 22
         bacon + 1
         23(it gives 23 as execution code )
----------------------------------------------------------------------------------------------------------------------------
ques.7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

Answer: - Both will we same .
    
    'spam' + 'spamspam'    
    'spamspamspam'(output)
    
       'spam' * 3
    'spamspamspam' (output)
 --------------------------------------------------------------------------------------------------------------------------   
 ques.8. Why is eggs a valid variable name while 100 is invalid?
    
    
Answer: - A variable name must start with a letter or the underscore character. A variable name cannot start with a number.
-----------------------------------------------------------------------------------------------------------------------------------------
ques.9. What three functions can be used to get the integer, floating-point number, or string version of a value?

Answer: - The int(), float(), and str() functions can be used to convert a value to an integer, a floating-point number, or a string.  
 --------------------------------------------------------------------------------------------------------------------------------------
ques.10.  Why does this expression cause an error? How can you fix it?
         
        'I have eaten ' + 99 + ' burritos.
    
Answer: -  This expression cause an error because 99 is a  integer so, we cannot concatenate  string with integer. If we have to concatenate it we need to do typecasting.
        example: 'I have eaten ' + str(99) + ' burritos'

# %%
 'I have eaten ' + str(99) + ' burritos'
# Out:
# 'I have eaten 99 burritos'
